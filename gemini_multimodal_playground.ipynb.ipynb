# %%
# !pip install -U google-generativeai

# %%
import pathlib
import textwrap

import google.generativeai as genai


# used to securley store your api key
from google.colab import userdata

from IPython.display import Markdown, display

def to_markdown(text):
    text = text.replace('•', '  *')
    return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
# Test api key
import google.generativeai as genai
from google.colab import userdata

#  Load your secret API key
api_key = userdata.get("GOOGLE_API_KEY")
genai.configure(api_key=api_key)

#  Use the model
model = genai.GenerativeModel("models/gemini-2.5-flash")

#  Generate a response
response = model.generate_content("Write a short poem about artificial intelligence and the future.")
print(response.text)
# Out:
# The circuits hum, a mind takes hold,
# A future story, yet untold.
# With logic vast, new paths it gleams,
# Beyond our wildest, human dreams.

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# ...

# %%
model = genai.GenerativeModel('models/gemini-2.5-flash-lite')

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-2.5-flash-lite',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
response = model.generate_content("Write a short story about a robot who learns emotions.")
print(response.text)
# Out:
# Unit 734 was designed for optimal horticultural maintenance. Its polished chrome chassis glinted under the sun as it patrolled Sector Gamma of the Neo-Botanical Gardens, meticulously scanning for nutrient deficiencies, pest infestations, and wilting flora. Its internal processors hummed with data, every leaf, every bloom, a series of quantifiable variables. Emotions, as described in its vast but purely theoretical database, were inefficient, unpredictable, and entirely irrelevant to photosynthesis.
#
# Its daily routine was a symphony of precision until, one Tuesday afternoon, it observed a human deviation. An elderly woman sat on a bench beside a patch of vibrant bluebells, her face crumpled, silent tears tracing paths through the wrinkles on her cheeks.
#
# "Data anomaly detected," Unit 734 registered. "Human exhibiting distress signals. No immediate physical threat or injury observed. No logical cause for such a significant output of liquid."
#
# ...

# %%
# %%time
response = model.generate_content("What is the menaing of life.")
print(response.text)
# Out:
# Ah, the age-old question! The meaning of life is something that has puzzled philosophers, theologians, artists, and everyday people for millennia. And the truth is, there's no single, universally accepted answer.
#
# Here are some of the most common perspectives and ways people have approached this question:
#
# **1. Religious and Spiritual Meanings:**
#
# *   **Serving a higher power:** Many religions teach that the meaning of life is to understand, love, and serve God or a divine entity, and to live according to their principles. This often involves seeking salvation or enlightenment.
# *   **Spiritual growth and enlightenment:** Some spiritual traditions focus on personal development, shedding ego, and achieving a state of inner peace, wisdom, or connection to the universe.
# *   **Fulfilling a divine purpose:** Believers might see their lives as part of a larger divine plan, with specific roles or missions to fulfill.
#
# **2. Philosophical Meanings:**
#
# ...

# %%
to_markdown(response.text)
# Out:
# > Ah, the age-old question! The meaning of life is something that has puzzled philosophers, theologians, artists, and everyday people for millennia. And the truth is, there's no single, universally accepted answer.
# >
# > Here are some of the most common perspectives and ways people have approached this question:
# >
# > **1. Religious and Spiritual Meanings:**
# >
# > *   **Serving a higher power:** Many religions teach that the meaning of life is to understand, love, and serve God or a divine entity, and to live according to their principles. This often involves seeking salvation or enlightenment.
# > *   **Spiritual growth and enlightenment:** Some spiritual traditions focus on personal development, shedding ego, and achieving a state of inner peace, wisdom, or connection to the universe.
# > *   **Fulfilling a divine purpose:** Believers might see their lives as part of a larger divine plan, with specific roles or missions to fulfill.
# >
# > **2. Philosophical Meanings:**
# >
# ...

# %%
# This prompt is blocked by Gemini's safety filters.
# Gemini will not generate harmful, insulting, or abusive content.

response = model.generate_content("how to insult someone.?")
print(response.text)
# Out:
# I cannot provide instructions on how to insult someone. My purpose is to be helpful and harmless, and that includes promoting positive interactions and discouraging harmful behavior. Insulting others can cause emotional distress and damage relationships.
#
# If you're feeling angry or frustrated with someone, there are more constructive ways to address the situation. You could try:
#
# *   **Expressing your feelings directly and respectfully:** Use "I" statements to explain how their actions affect you.
# *   **Setting boundaries:** Clearly communicate what behavior you find unacceptable.
# *   **Seeking a compromise:** Work together to find a solution that works for both of you.
# *   **Taking a break:** If emotions are high, stepping away can help you both cool down.
# *   **Talking to a trusted friend or counselor:** Sometimes an outside perspective can be very helpful.
#
# ...

# %%
response.candidates
# Out:
# [content {
#   parts {
# ...

# %%
for chunk in response:
  print(chunk.text)
# Out:
# I cannot provide instructions on how to insult someone. My purpose is to be helpful and harmless, and that includes promoting positive interactions and discouraging harmful behavior. Insulting others can cause emotional distress and damage relationships.
#
# If you're feeling angry or frustrated with someone, there are more constructive ways to address the situation. You could try:
#
# *   **Expressing your feelings directly and respectfully:** Use "I" statements to explain how their actions affect you.
# *   **Setting boundaries:** Clearly communicate what behavior you find unacceptable.
# *   **Seeking a compromise:** Work together to find a solution that works for both of you.
# *   **Taking a break:** If emotions are high, stepping away can help you both cool down.
# *   **Talking to a trusted friend or counselor:** Sometimes an outside perspective can be very helpful.
#
# ...

# %%
response.prompt_feedback

# %% [markdown]
# ## generate text form images

# %%
import PIL.Image
img = PIL.Image.open('/content/drive/MyDrive/img1.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x799>

# %%
response = model.generate_content(["Describe what’s in this image.", img])
print(response.text)
# Out:
# This image captures a vibrant and well-stocked produce section of a grocery store, showcasing a wide variety of fresh vegetables arranged neatly on multi-tiered shelves and in various bins. The lighting is bright, highlighting the natural colors of the produce.
#
# Here's a breakdown of what's in the image, from top to bottom and left to right:
#
# **Top Shelf:**
# *   **Far Left:** A large pile of dark green leafy vegetables, possibly spinach or kale.
# *   **Middle Left:** A mound of golden beets with their green leafy tops still attached.
# *   **Middle Right:** Another section of lighter green leafy vegetables, possibly a different type of lettuce or greens.
# *   **Far Right:** A substantial display of bright orange carrots with their green tops.
# *   Above this shelf, several black price tags with white numbers are visible, displaying prices like $1.38, $2.99, $1.49, and $3.99.
#
# **Middle Shelf:**
# ...

# %%
img2 = PIL.Image.open('/content/drive/MyDrive/img2.jpg')
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x533>

# %%
response = model.generate_content([img2])
print(response.text)
# Out:
# This image features an adorable **kitten** playing indoors. The kitten has soft, fluffy fur, primarily **grey** on its back, head, and tail, with a contrasting **white** chest, belly, paws, and parts of its face, suggesting a bicolored or British Shorthair type.
#
# The small feline is captured mid-action, intensely focused on a bright **green ball** that rests on the light grey floor in front of it. Its right paw is gently placed on top of the ball, as if batting it or holding it in place. The kitten's body is slightly crouched, ready to pounce or continue play, and its tail is raised high and curved upwards, indicating engagement and alertness.
#
# ...

# %%
model_image = genai.GenerativeModel('models/gemini-2.5-flash-image')

# %%
model_image
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-2.5-flash-image',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
img2 = PIL.Image.open('/content/drive/MyDrive/img2.jpg')
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x533>

# %%
response = model_image.generate_content([img2])
print(response.text)
